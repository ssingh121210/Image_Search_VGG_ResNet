# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import os, glob, shutil
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import tensorflow as tf
import matplotlib.image as mpimg
from IPython.display import Image
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import VGG16
from numpy import asarray
from numpy import savetxt
from numpy import loadtxt
import shutil
import random
import pandas as pd
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense,Dropout
from keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
IMAGE_DIR =r'C:\Users\ashok kumar\Avantari\dataset'

os.chdir(IMAGE_DIR)
os.getcwd()
# Out:
# 'C:\\Users\\ashok kumar\\Avantari\\dataset'

# %%
image_files = os.listdir()
print(len(image_files))
# Out:
# 4738

# %%
image_4 = mpimg.imread(image_files[0])
plt.imshow(image_4)
plt.show()

# %%
cv2.imread(image_files[1]).shape
# Out:
# (512, 512, 3)

# %% [markdown]
# # Model 1 : Transfer Learning

# %%
model = VGG16(weights='imagenet', include_top=False)
model.summary()

img = image.load_img(image_files[0], target_size=(224, 224))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = preprocess_input(img_data)

vgg16_feature = model.predict(img_data)

print(vgg16_feature.shape)
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...

# %%
vgg16_feature_list = []
for _ in image_files:
        img = image.load_img(_, target_size=(224, 224))
        img_data = image.img_to_array(img)
        img_data = np.expand_dims(img_data, axis=0)
        img_data = preprocess_input(img_data)

        vgg16_feature = model.predict(img_data)
        vgg16_feature_np = np.array(vgg16_feature)
        vgg16_feature_list.append(vgg16_feature_np.flatten())
        
vgg16_feature_list_np = np.array(vgg16_feature_list)

# %%
type(vgg16_feature_list_np)
# Out:
# numpy.ndarray

# %%
savetxt('vgg16_feature_list_np.csv', vgg16_feature_list_np, delimiter=',')

# %%
vgg16_feature_list_np = loadtxt(r'C:\Users\ashok kumar\Avantari\vgg16_feature_list_np.csv', delimiter=',')
print(vgg16_feature_list_np)
# Out:
# [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.          0.         19.36047935 ...  0.          0.
#    0.        ]
#  [ 0.          0.         80.03522491 ...  0.90635103  0.
#   46.75410461]
#  ...
#  [ 0.          0.          0.         ...  0.         14.79490471
#    0.        ]
#  [ 0.          0.          0.         ...  0.          9.08301735
#    0.        ]
#  [ 0.          0.          0.         ...  0.         10.52792168
#    0.        ]]

# %%
sil = []
kl = []
kmax = 10
for k in range(2, kmax+1):
    kmeans2 = KMeans(n_clusters = k).fit(vgg16_feature_list_np)
    labels = kmeans2.labels_
    sil.append(silhouette_score(vgg16_feature_list_np, labels, metric = 'euclidean'))
    kl.append(k)

# %%
plt.plot(kl, sil)
plt.ylabel('Silhoutte Score')
plt.xlabel('K')
plt.show()

# %%
kmeans_final = KMeans(n_clusters = 6).fit(vgg16_feature_list_np)

# %%
op=r'C:\Users\ashok kumar\Avantari'

# %%
for _ in range(len(kmeans_final.labels_)):
    shutil.copy(image_files[_],os.path.join(op,str(kmeans_final.labels_[_])))

# %%
inpu_file=str(input("Enter the Name of the file ?\n"))
img = image.load_img(inpu_file, target_size=(224, 224))
img_data = image.img_to_array(img)
img_data = np.expand_dims(img_data, axis=0)
img_data = preprocess_input(img_data)
vgg16_feature = model.predict(img_data)
vgg16_feature_np = np.array(vgg16_feature)
vgg16_feature_np = vgg16_feature_np.flatten()
Number=int(input("No. of Images ?\n"))
path =os.path.join(op,str(kmeans_final.predict([vgg16_feature_np])[0]))
files = os.listdir(path)
index = random.randrange(0,Number)
image_2 = mpimg.imread(inpu_file)
plt.imshow(image_2)
plt.show()
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
        fig.add_subplot(rows, columns, i)
        image_3 = mpimg.imread(files[i])
        plt.imshow(image_3)
plt.show()
# Out:
# Enter the Name of the file ?
# 2342.jpg
# No. of Images ?
# 9

# %% [markdown]
# ## CNN Model For Classification(ResNet Transfer Learning) :

# %%
from keras.applications.resnet50 import ResNet50, preprocess_input
HEIGHT = 300
WIDTH = 300
base_model = ResNet50(weights='imagenet', 
                      include_top=False, 
                      input_shape=(HEIGHT, WIDTH, 3))
# Out:
# C:\Users\ashok kumar\Anaconda3\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '

# %%
from keras.preprocessing.image import ImageDataGenerator
TEST_DIR=r"C:\Users\ashok kumar\Avantari\Classification/test"
TRAIN_DIR = r"C:\Users\ashok kumar\Avantari\Classification/Train/Train"
HEIGHT = 300
WIDTH = 300
BATCH_SIZE = 8

train_datagen =  ImageDataGenerator(
      preprocessing_function=preprocess_input,
      rotation_range=90,
      horizontal_flip=True,
      vertical_flip=True
    )
test_datagen = ImageDataGenerator()


train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(HEIGHT, WIDTH), 
                                                    batch_size=BATCH_SIZE)
test_set = test_datagen.flow_from_directory(
        TEST_DIR,
        target_size=(HEIGHT, WIDTH), 
        batch_size=BATCH_SIZE)

# %%
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.models import Sequential, Model

def build_finetune_model(base_model, dropout, fc_layers, num_classes):
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output
    x = Flatten()(x)
    for fc in fc_layers:
        # New FC layer, random init
        x = Dropout(dropout)(x)
        x = Dense(fc, activation='relu')(x) 
        x = Dropout(dropout)(x)

    # New softmax layer
    predictions = Dense(num_classes, activation='softmax')(x) 
    
    finetune_model = Model(inputs=base_model.input, outputs=predictions)

    return finetune_model

class_list = ["0", "1", "2","3","4","5"]
FC_LAYERS = [1024, 1024]
dropout = 0.2

finetune_model = build_finetune_model(base_model, 
                                      dropout=dropout, 
                                      fc_layers=FC_LAYERS, 
                                      num_classes=len(class_list))

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=10)

# %%
from keras.optimizers import SGD, Adam
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

NUM_EPOCHS = 10
BATCH_SIZE = 8
num_train_images = 4738 

adam = Adam(lr=0.00001)
finetune_model.compile(adam, loss='categorical_crossentropy', metrics=['accuracy'])

callbacks_list = [es]

history = finetune_model.fit_generator(train_generator, epochs=NUM_EPOCHS, workers=16, 
                                       steps_per_epoch=num_train_images // BATCH_SIZE, 
                                       shuffle=True, callbacks=callbacks_list,validation_data=test_set)

from keras.models import load_model

finetune_model.save('/content/drive/My Drive/my_model.h5')

# %% [markdown]
# # Model 3 : Custom Model

# %%
classifier=Sequential()
classifier.add(Conv2D(32,3,3,input_shape=(64,64,3),activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Flatten())
classifier.add(Dropout(0.2))
classifier.add(Dense(output_dim=128,activation='relu'))
classifier.add(Dropout(0.2))
classifier.add(Dense(output_dim=1,activation='sigmoid'))

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
training_set = train_datagen.flow_from_directory(
        '/content/drive/My Drive/train_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
test_set = test_datagen.flow_from_directory(
        '/content/drive/My Drive/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')

classifier.fit_generator(
        training_set,
        steps_per_epoch=100,
        epochs=5,
        validation_data=test_set,
        validation_steps=10)
